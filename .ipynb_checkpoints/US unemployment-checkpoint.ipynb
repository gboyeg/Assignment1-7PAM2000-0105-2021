# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
unemployment = pd.read_csv("unemployment_data_us.csv")
unemployment
# Out:
#      Year Month  Primary_School      Date  High_School  Associates_Degree  \
# 0    2010   Jan            15.3  Jan-2010         10.2                8.6
# 1    2011   Jan            14.3  Jan-2011          9.5                8.1
# 2    2012   Jan            13.0  Jan-2012          8.5                7.1
# 3    2013   Jan            12.0  Jan-2013          8.1                6.9
# 4    2014   Jan             9.4  Jan-2014          6.5                5.9
# ..    ...   ...             ...       ...          ...                ...
# 127  2016   Dec             7.5  Dec-2016          5.1                3.8
# 128  2017   Dec             6.2  Dec-2017          4.2                3.6
# 129  2018   Dec             5.8  Dec-2018          3.8                3.3
# 130  2019   Dec             5.2  Dec-2019          3.7                2.7
# 131  2020   Dec             NaN  Dec-2020          NaN                NaN
#
#      Professional_Degree  White  Black  Asian  Hispanic   Men  Women
# ...

# %%
Asian = unemployment['Asian']
Asian
# Out:
# 0      8.3
# 1      6.8
# 2      6.7
# 3      6.4
# 4      4.7
#       ...
# 127    2.7
# 128    2.5
# 129    3.3
# 130    2.5
# 131    NaN
# Name: Asian, Length: 132, dtype: float64

# %%
Black = unemployment['Black']
Black
# Out:
# 0      16.5
# 1      15.8
# 2      13.6
# 3      13.7
# 4      12.1
#        ...
# 127     7.9
# 128     6.7
# 129     6.6
# 130     5.9
# 131     NaN
# Name: Black, Length: 132, dtype: float64

# %%
Hispanic = unemployment['Hispanic']
Hispanic
# Out:
# 0      12.9
# 1      12.3
# 2      10.7
# 3       9.7
# 4       8.3
#        ...
# 127     5.9
# 128     5.0
# 129     4.4
# 130     4.2
# 131     NaN
# Name: Hispanic, Length: 132, dtype: float64

# %%
#sort by year

# %%
plt.figure()
plt.plot(Black, label='Black')
plt.plot(Hispanic, label='Hispanic')
plt.legend()
plt.show()

# %%
plt.figure()
fig, ax = plt.subplots(1, 1)
level = 
plt.violinplot(Year)

ax.set_xticks([1, 2, 3, 4])
ax.set_xticklabels(ret)
plt.show()

# %%
unemployment.groupby(unemployment['Year']).sum()
# Out:
#       Primary_School  High_School  Associates_Degree  Professional_Degree  \
# Year
# 2010           178.1        123.5              100.6                 56.5
# 2011           168.9        113.1               95.6                 51.7
# 2012           148.7         99.7               85.2                 48.3
# 2013           131.5         90.1               76.4                 44.4
# 2014           108.2         72.1               65.1                 38.1
# 2015            95.3         65.3               54.1                 30.8
# 2016            89.2         62.3               49.0                 30.1
# 2017            78.1         55.8               45.0                 27.8
# 2018            67.3         48.5               39.8                 25.5
# 2019            64.2         43.9               36.3                 25.1
# 2020            18.0         11.8                9.5                  6.4
#
#       White  Black  Asian  Hispanic    Men  Women
# Year
# ...

# %%
print(unemployment.columns)
Men = unemployment['Men']
Women = unemployment['Women']

plt.figure()
plt.hist(Men, label='Men', density=True, color='g', alpha=0.5, range=(3,11))
plt.hist(Women, label='Women', density=True, color='b', alpha=0.5, range=(3,11))

plt.legend()
plt.show()
# Out:
# Index(['Year', 'Month', 'Primary_School', 'Date', 'High_School',
#        'Associates_Degree', 'Professional_Degree', 'White', 'Black', 'Asian',
#        'Hispanic', 'Men', 'Women'],
#       dtype='object')

# %%
Men = unemployment['Men']
Men
